# %% [markdown]
# # Data Visualization

# %% [markdown]
# ## Opening the csv files

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ## Tagalog to Ilokano

# %%
# Read the data
df_bleu_sd_tl_il = pd.read_csv('../src/scores/Tagalog to Ilokano/Standard Translator/test/test_bleu_tl-il.csv')
df_bleu_hb_tl_il = pd.read_csv('../src/scores/Tagalog to Ilokano/Hybrid Translator/test/test_bleu_tl-il.csv')

# %%
df_bleu_hb_tl_il.head()
# Out:
#                                                INPUT  \
# 0                                               EZRA
# 1  Nang unang taon nga ni Ciro na hari sa Persia ...
# 2  Ganito ang sabi ni Ciro na hari sa Persia Ibin...
# 3  Sinoman sa inyo sa kaniyang buong bayan sumaka...
# 4  At sinomang naiwan sa alinmang dako na kaniyan...
#
#                                            REFERENCE  \
# 0                                             esdras
# 1  idi umuna a tawen ni ciro nga ari ti persia ta...
# 2  castoy ti cuna ni ciro nga ari ti persia isuam...
# 3  uray siasinoman nga adda cadacayo amin nga ili...
# 4  ken uray siasinoman a mabati iti uray ania a d...
#
#                                  MACHINE_TRANSLATION  BREVITY_PENALTY  \
# 0                                             esdras         1.000000
# 1  idi umuna tawen nga ni ciro a babaonen iti per...         1.000000
# 2  ganito ti cuna ni ciro a babaonen iti persia i...         0.928571
# 3  siasinoman iti jehova iti isu amin ilili sumak...         1.000000
# 4  ket siasinoman an iti alinmang lugar a isu sic...         1.000000
#
#    GEOMETRIC_AVE  BLEU_SCORE  AVERAGE_BLEU_SCORE
# 0       1.000000    1.000000                 NaN
# 1       0.544030    0.544030                 NaN
# 2       0.557228    0.517426                 NaN
# 3       0.640713    0.640713                 NaN
# 4       0.462606    0.462606                 NaN

# %% [markdown]
# # Creating the vizualization

# %%
# Comparing the histograms of the two models
fig, ax = plt.subplots(1, 2, figsize=(15, 5))
sns.histplot(df_bleu_sd_tl_il['BLEU_SCORE'], ax=ax[0], color='blue')
sns.histplot(df_bleu_hb_tl_il['BLEU_SCORE'], ax=ax[1], color='red')
ax[0].set_title('Standard Translator')
ax[1].set_title('Hybrid Translator')
fig.suptitle('BLEU Score Distribution (Tagalog to Ilokano)')
plt.show()
