# %% [markdown]
# # BLEU Scoring

# %% [markdown]
# ## TRAINING DATA SCORES

# %% [markdown]
# ### Tagalog to Ilokano

# %%
import pandas as pd

# Read the Tagalog to Ilokano Training Data Results
dict_tl_il_result = pd.read_json('../src/json data/Tagalog to Ilokano/Hybrid Translator/dict_op_ex.json')

source_text_list = dict_tl_il_result['Source Text'].tolist()
system_op_list = dict_tl_il_result['System Output'].tolist()
target_op_list = dict_tl_il_result['Target Output'].tolist()

# %%
from nltk.translate.bleu_score import SmoothingFunction, sentence_bleu

def bleuScore(target_op, system_op):
    cc = SmoothingFunction() # Smoothing is used for short sentences or sentences without 3/4-grams
    return sentence_bleu([target_op], system_op, smoothing_function=cc.method4) # Sentence_blue() requires sentences to be tokenized list

with open("../src/scores/txt/train_bleu_tl-il.txt","w", encoding="utf-8") as df:
    temp_index = 0
    total_bleu_score = 0
    low_total_bleu_score = 0
    score_list = []
    data = []

    csv_frame = pd.DataFrame(data, columns=["INPUT", "REFERENCE", "MACHINE_TRANSLATION", "BLEU_SCORE"])
    low_csv_frame = pd.DataFrame(data, columns=["INPUT", "REFERENCE", "MACHINE_TRANSLATION", "BLEU_SCORE"])

    for target_op in target_op_list:
        system_op = system_op_list[temp_index]
        source_text = source_text_list[temp_index]

        score = bleuScore(target_op, system_op)
      
        #Writing the result to a txt file
        df.write("Input: " + source_text + "\n")
        df.write("Reference: " + target_op + "\n")
        df.write("Machine Translation: " + system_op + "\n")
        df.write("BLEU Score: " + str(score) + "\n")
        df.write("\n")
        
        #Writing the result in a csv file
        csv_frame = csv_frame.append({"INPUT": source_text, "REFERENCE": target_op, "MACHINE_TRANSLATION": system_op, "BLEU_SCORE": score}, ignore_index=True)
        csv_frame.to_csv('../src/scores/csv/train_bleu_tl-il.csv', index=False)

        #Filtering low bleu scores
        if score < .70:
            with open("../src/scores/txt/train_low_bleu_tl-il.txt","a", encoding="utf-8") as low:
                low.write("Input: " + source_text + "\n")
                low.write("Reference: " + target_op + "\n")
                low.write("Machine Translation: " + system_op + "\n")
                low.write("BLEU Score: " + str(score) + "\n")
                low.write("\n")

            low_total_bleu_score += score
            low_csv_frame = low_csv_frame.append({"INPUT": source_text, "REFERENCE": target_op, "MACHINE_TRANSLATION": system_op, "BLEU_SCORE": score}, ignore_index=True)
            low_csv_frame.to_csv('../src/scores/csv/train_low_bleu_tl-il.csv', index=False)

        score_list.append(score)
        total_bleu_score += score
        temp_index += 1

    dict_tl_il_result['BLEU Score'] = score_list
    average_bleu_score = total_bleu_score / len(target_op_list)
    low_average_bleu_score = low_total_bleu_score / len(target_op_list)
    
    #Writing the Avg BLEU in a txt file
    df.write("Average BLEU Score: " + str(average_bleu_score))
    with open("../src/scores/txt/train_low_bleu_tl-il.txt","a", encoding="utf-8") as low:
        low.write("Average BLEU Score:" + str(low_average_bleu_score))

    #Writing the Avg BLEU in a csv file
    csv_frame = csv_frame.append({"AVERAGE BLEU SCORE": average_bleu_score}, ignore_index=True)
    csv_frame.to_csv('../src/scores/csv/train_bleu_tl-il.csv', index=False)

    low_csv_frame = csv_frame.append({"AVERAGE BLEU SCORE": low_average_bleu_score}, ignore_index=True)
    low_csv_frame.to_csv('../src/scores/csv/train_low_bleu_tl-il.csv', index=False)

# %% [markdown]
# ### Ilokano to Tagalog

# %%
# Read the Ilokano to Tagalog Trainig Data Results
dict_il_tl_result = pd.read_json('../src/json data/Ilokano to Tagalog/Hybrid Translator/dict_il_op_ex.json')

source_text_list = dict_il_tl_result['Source Text'].tolist()
target_op_list = dict_il_tl_result['Target Output'].tolist()
system_op_list = dict_il_tl_result['System Output'].tolist()

# %%
with open("../src/scores/txt/train_bleu_il-tl.txt","w", encoding="utf-8") as df:
    temp_index = 0
    total_bleu_score = 0
    low_total_bleu_score = 0
    score_list = []
    data = []

    csv_frame = pd.DataFrame(data, columns=["INPUT", "REFERENCE", "MACHINE_TRANSLATION", "BLEU_SCORE"])
    low_csv_frame = pd.DataFrame(data, columns=["INPUT", "REFERENCE", "MACHINE_TRANSLATION", "BLEU_SCORE"])

    for target_op in target_op_list:
        system_op = system_op_list[temp_index]
        source_text = source_text_list[temp_index]

        score = bleuScore(target_op, system_op)
      
        #Writing the result to a txt file
        df.write("Input: " + source_text + "\n")
        df.write("Reference: " + target_op + "\n")
        df.write("Machine Translation: " + system_op + "\n")
        df.write("BLEU Score: " + str(score) + "\n")
        df.write("\n")
        
        #Writing the result in a csv file
        csv_frame = csv_frame.append({"INPUT": source_text, "REFERENCE": target_op, "MACHINE_TRANSLATION": system_op, "BLEU_SCORE": score}, ignore_index=True)
        csv_frame.to_csv('../src/scores/csv/train_bleu_il-tl.csv', index=False)

        #Filtering low bleu scores
        if score < .70:
            with open("../src/scores/txt/train_low_bleu_il-tl.txt","a", encoding="utf-8") as low:
                low.write("Input: " + source_text + "\n")
                low.write("Reference: " + target_op + "\n")
                low.write("Machine Translation: " + system_op + "\n")
                low.write("BLEU Score: " + str(score) + "\n")
                low.write("\n")

            low_total_bleu_score += score
            low_csv_frame = low_csv_frame.append({"INPUT": source_text, "REFERENCE": target_op, "MACHINE_TRANSLATION": system_op, "BLEU_SCORE": score}, ignore_index=True)
            low_csv_frame.to_csv('../src/scores/csv/train_low_bleu_il-tl.csv', index=False)

        score_list.append(score)
        total_bleu_score += score
        temp_index += 1

    dict_tl_il_result['BLEU Score'] = score_list
    average_bleu_score = total_bleu_score / len(target_op_list)
    low_average_bleu_score = low_total_bleu_score / len(target_op_list)
    
    #Writing the Avg BLEU in a txt file
    df.write("Average BLEU Score: " + str(average_bleu_score))
    with open("../src/scores/txt/train_low_bleu_il-tl.txt","a", encoding="utf-8") as low:
        low.write("Average BLEU Score:" + str(low_average_bleu_score))

    #Writing the Avg BLEU in a csv file
    csv_frame = csv_frame.append({"AVERAGE BLEU SCORE": average_bleu_score}, ignore_index=True)
    csv_frame.to_csv('../src/scores/csv/train_bleu_il-tl.csv', index=False)

    low_csv_frame = csv_frame.append({"AVERAGE BLEU SCORE": low_average_bleu_score}, ignore_index=True)
    low_csv_frame.to_csv('../src/scores/csv/train_low_bleu_il-tl.csv', index=False)

# %% [markdown]
# ## TESTING DATA SCORES

# %% [markdown]
# ### Tagalog to Ilokano

# %%
# Read the Tagalog to Ilokano Testing Data Results
dict_tl_il_result = pd.read_json('../src/json data/Tagalog to Ilokano/Hybrid Translator/dict_tl-il_test.json')

source_text_list = dict_tl_il_result['Source Text'].tolist()
system_op_list = dict_tl_il_result['System Output'].tolist()
target_op_list = dict_tl_il_result['Target Output'].tolist()

# %%
with open("../src/scores/txt/test_bleu_tl-il.txt","w", encoding="utf-8") as df:
    temp_index = 0
    total_bleu_score = 0
    low_total_bleu_score = 0
    score_list = []
    data = []

    csv_frame = pd.DataFrame(data, columns=["INPUT", "REFERENCE", "MACHINE_TRANSLATION", "BLEU_SCORE"])
    low_csv_frame = pd.DataFrame(data, columns=["INPUT", "REFERENCE", "MACHINE_TRANSLATION", "BLEU_SCORE"])

    for target_op in target_op_list:
        system_op = system_op_list[temp_index]
        source_text = source_text_list[temp_index]

        score = bleuScore(target_op, system_op)
      
        #Writing the result to a txt file
        df.write("Input: " + source_text + "\n")
        df.write("Reference: " + target_op + "\n")
        df.write("Machine Translation: " + system_op + "\n")
        df.write("BLEU Score: " + str(score) + "\n")
        df.write("\n")
        
        #Writing the result in a csv file
        csv_frame = csv_frame.append({"INPUT": source_text, "REFERENCE": target_op, "MACHINE_TRANSLATION": system_op, "BLEU_SCORE": score}, ignore_index=True)
        csv_frame.to_csv('../src/scores/csv/test_bleu_tl-il.csv', index=False)

        #Filtering low bleu scores
        if score < .70:
            with open("../src/scores/txt/test_low_bleu_tl-il.txt","a", encoding="utf-8") as low:
                low.write("Input: " + source_text + "\n")
                low.write("Reference: " + target_op + "\n")
                low.write("Machine Translation: " + system_op + "\n")
                low.write("BLEU Score: " + str(score) + "\n")
                low.write("\n")

            low_total_bleu_score += score
            low_csv_frame = low_csv_frame.append({"INPUT": source_text, "REFERENCE": target_op, "MACHINE_TRANSLATION": system_op, "BLEU_SCORE": score}, ignore_index=True)
            low_csv_frame.to_csv('../src/scores/csv/test_low_bleu_tl-il.csv', index=False)

        score_list.append(score)
        total_bleu_score += score
        temp_index += 1

    dict_tl_il_result['BLEU Score'] = score_list
    average_bleu_score = total_bleu_score / len(target_op_list)
    low_average_bleu_score = low_total_bleu_score / len(target_op_list)
    
    #Writing the Avg BLEU in a txt file
    df.write("Average BLEU Score: " + str(average_bleu_score))
    with open("../src/scores/txt/test_low_bleu_tl-il.txt","a", encoding="utf-8") as low:
        low.write("Average BLEU Score:" + str(low_average_bleu_score))

    #Writing the Avg BLEU in a csv file
    csv_frame = csv_frame.append({"AVERAGE BLEU SCORE": average_bleu_score}, ignore_index=True)
    csv_frame.to_csv('../src/scores/csv/test_bleu_tl-il.csv', index=False)

    low_csv_frame = low_csv_frame.append({"AVERAGE BLEU SCORE": low_average_bleu_score}, ignore_index=True)
    low_csv_frame.to_csv('../src/scores/csv/test_low_bleu_tl-il.csv', index=False)

# %% [markdown]
# ### Ilokano to Tagalog

# %%
# Read the Tagalog to Ilokano Testing Data Results
dict_tl_il_result = pd.read_json('../src/json data/Ilokano to Tagalog/Hybrid Translator/dict_il-tl_test.json')

source_text_list = dict_tl_il_result['Source Text'].tolist()
system_op_list = dict_tl_il_result['System Output'].tolist()
target_op_list = dict_tl_il_result['Target Output'].tolist()

# %%
with open("../src/scores/txt/test_bleu_il-tl.txt","w", encoding="utf-8") as df:
    temp_index = 0
    total_bleu_score = 0
    low_total_bleu_score = 0
    score_list = []
    data = []

    csv_frame = pd.DataFrame(data, columns=["INPUT", "REFERENCE", "MACHINE_TRANSLATION", "BLEU_SCORE"])
    low_csv_frame = pd.DataFrame(data, columns=["INPUT", "REFERENCE", "MACHINE_TRANSLATION", "BLEU_SCORE"])

    for target_op in target_op_list:
        system_op = system_op_list[temp_index]
        source_text = source_text_list[temp_index]

        score = bleuScore(target_op, system_op)
      
        #Writing the result to a txt file
        df.write("Input: " + source_text + "\n")
        df.write("Reference: " + target_op + "\n")
        df.write("Machine Translation: " + system_op + "\n")
        df.write("BLEU Score: " + str(score) + "\n")
        df.write("\n")
        
        #Writing the result in a csv file
        csv_frame = csv_frame.append({"INPUT": source_text, "REFERENCE": target_op, "MACHINE_TRANSLATION": system_op, "BLEU_SCORE": score}, ignore_index=True)
        csv_frame.to_csv('../src/scores/csv/test_bleu_il-tl.csv', index=False)

        #Filtering low bleu scores
        if score < .70:
            with open("../src/scores/txt/test_low_bleu_il-tl.txt","a", encoding="utf-8") as low:
                low.write("Input: " + source_text + "\n")
                low.write("Reference: " + target_op + "\n")
                low.write("Machine Translation: " + system_op + "\n")
                low.write("BLEU Score: " + str(score) + "\n")
                low.write("\n")

            low_total_bleu_score += score
            low_csv_frame = low_csv_frame.append({"INPUT": source_text, "REFERENCE": target_op, "MACHINE_TRANSLATION": system_op, "BLEU_SCORE": score}, ignore_index=True)
            low_csv_frame.to_csv('../src/scores/csv/test_low_bleu_il-tl.csv', index=False)

        score_list.append(score)
        total_bleu_score += score
        temp_index += 1

    dict_tl_il_result['BLEU Score'] = score_list
    average_bleu_score = total_bleu_score / len(target_op_list)
    low_average_bleu_score = low_total_bleu_score / len(target_op_list)
    
    #Writing the Avg BLEU in a txt file
    df.write("Average BLEU Score: " + str(average_bleu_score))
    with open("../src/scores/txt/test_low_bleu_il-tl.txt","a", encoding="utf-8") as low:
        low.write("Average BLEU Score:" + str(low_average_bleu_score))

    #Writing the Avg BLEU in a csv file
    csv_frame = csv_frame.append({"AVERAGE BLEU SCORE": average_bleu_score}, ignore_index=True)
    csv_frame.to_csv('../src/scores/csv/test_bleu_il-tl.csv', index=False)

    low_csv_frame = low_csv_frame.append({"AVERAGE BLEU SCORE": low_average_bleu_score}, ignore_index=True)
    low_csv_frame.to_csv('../src/scores/csv/test_low_bleu_il-tl.csv', index=False)
